# %% [markdown]
# # Transformers arxetekturasini vizual korish uchun sayt
# https://poloclub.github.io/transformer-explainer/
#
# # Transformers arxetekturasini vizual korish uchun saytni github akkaunti
# https://github.com/poloclub/transformer-explainer
