# %%
import unicodedata


def get_stats(ids, counts=None):
    """
    funksiya sonlardan iborat ro'yhat qabul qiladi misol uchun:[1,2,3,1,2] va 
    ikkita o'xshash ketma kelikni sanab javobini dict ko'rinishida qaytaradi
    misol: [1, 2, 3, 1, 2] -> {(1, 2): 2, (2, 3): 1, (3, 1): 1}
    """
    counts = {} if counts is None else counts
    for pair in zip(ids, ids[1:]):
        counts[pair] = counts.get(pair, 0) + 1
        
    return counts


get_stats([1,2,3,1,2,3])
# Out:
# {(1, 2): 2, (2, 3): 2, (3, 1): 1}

# %%
def merge(ids, pair, idx):
    """
    Funksiya quyidagi elementlarni qabul qiladi 
    Misol: ids=[1, 2, 3, 1, 2], pair=(1, 2), idx=4 -> [4, 3, 4]
    va natijani ro'yhat ko'rinishda qaytaradi yani o'xshash juftliklarga 
    yangi sonlar biriktiriladi.
    """
    newids = []
    i = 0
    
    while i < len(ids):
        if ids[i] == pair[0] and i < len(ids) -1 and ids[i+1] == pair[1]:
            newids.append(idx)
            i += 2
        else:
            newids.append(ids[i])
            i += 1
    
    return newids


merge([1,2,3,1,2], (1, 2), 4)
# Out:
# [4, 3, 4]

# %%
def replace_control_characters(s: str) -> str:
    """
    This function cleans a string. It removes 
    “control characters” (control characters = special 
    invisible characters like newline \n, tab \t, or 
    other Unicode characters that can break output).
    
    It looks at each character in the string.
    If the character is normal (letter, number, punctuation), it keeps it.
    If the character is a control character, it replaces it with a text version like \u000a.
    """
    chars = []
    for ch in s:
        if unicodedata.category(ch)[0] != "C":
            chars.append(ch) # this character is ok
        else:
            chars.append(f"\\u{ord(ch):04x}")
    return "".join(chars)

# %%
def render_token(t: bytes) -> str:
    """
    It takes a value t that is bytes.
    Example: b"hello" or b"\xe2\x98\x83".
    It converts these bytes into a UTF-8 string.
    If some bytes are broken or invalid, they are replaced with "�".
    It calls replace_control_characters() to clean the string and make sure no control characters remain.
    It returns the final safe string.
    Example: t = b"hi\nthere" -> "hi\u000athere"
    """
    s = t.decode('utf-8', errors='replace')
    s = replace_control_characters(s)
    return s
    
    
render_token(b"hi\nthere")
# Out:
# 'hi\\u000athere'
